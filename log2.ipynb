# %% [markdown]
# <a href="https://colab.research.google.com/github/SirisPudasai/Gitproject/blob/master/log2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('tested.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df=df.drop(columns=['Cabin'])

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
sns.countplot(x='Survived',data =df,hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Fare']=df['Fare'].fillna(df['Fare'].mean())

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
df['Gender']=pd.get_dummies(df['Sex'],drop_first=True)

# %%
df=df.drop(columns=['Name','Sex','Embarked','Ticket'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass       Age  SibSp  Parch      Fare  Gender
# 0            892         0       3  34.50000      0      0    7.8292    True
# 1            893         1       3  47.00000      1      0    7.0000   False
# 2            894         0       2  62.00000      0      0    9.6875    True
# 3            895         0       3  27.00000      0      0    8.6625    True
# 4            896         1       3  22.00000      1      1   12.2875   False
# ..           ...       ...     ...       ...    ...    ...       ...     ...
# 413         1305         0       3  30.27259      0      0    8.0500    True
# 414         1306         1       1  39.00000      0      0  108.9000   False
# 415         1307         0       3  38.50000      0      0    7.2500    True
# 416         1308         0       3  30.27259      0      0    8.0500    True
# 417         1309         0       3  30.27259      1      1   22.3583    True
#
# [418 rows x 8 columns]

# %%
df

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Gender         0
# dtype: int64

# %%
X_lst=df[[
    'PassengerId',
    'Pclass',
    'Age',
    'SibSp',
    'Parch',
    'Fare',
    'Gender'
]]
y=df['Survived']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_lst,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
log_model=LogisticRegression()
log_model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predict=log_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
pd.DataFrame(confusion_matrix(y_test,predict),index=['Actual No','Actual Yes'],columns=['Predict No','Predict Yes'])
# Out:
#             Predict No  Predict Yes
# Actual No           50            0
# Actual Yes           0           34

# %%
from sklearn.metrics import accuracy_score
y_pred=log_model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0
